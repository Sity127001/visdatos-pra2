# %% [markdown]
# # EDA — Dataset principal (road_eqr_carpda)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 50)

print("Imports OK")
# Out:
# Imports OK

# %%
# Cargar dataset principal
#usamos ruta relativa: ya que el notebook está en la carpeta notebooks/, para acceder a la carpeta data necesitamos 
#subir un nivel (de notebooks/ a  visdatos-pra2/ - para ello ponemos ".."). luego entramos en data/. luego el archivo.
df = pd.read_csv("../data/estat_road_eqr_carpda_en.csv.gz", compression="gzip")
df.head()
# Out:
#                      DATAFLOW        LAST UPDATE freq unit mot_nrg geo  \
# 0  ESTAT:ROAD_EQR_CARPDA(1.0)  24/03/26 23:00:00    A   NR     ALT  AL
# 1  ESTAT:ROAD_EQR_CARPDA(1.0)  24/03/26 23:00:00    A   NR     ALT  AL
# 2  ESTAT:ROAD_EQR_CARPDA(1.0)  24/03/26 23:00:00    A   NR     ALT  AL
# 3  ESTAT:ROAD_EQR_CARPDA(1.0)  24/03/26 23:00:00    A   NR     ALT  AL
# 4  ESTAT:ROAD_EQR_CARPDA(1.0)  24/03/26 23:00:00    A   NR     ALT  AL
#
#    TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 0         2019     3757.0      NaN          NaN
# 1         2020      372.0      NaN          NaN
# 2         2021     5703.0      NaN          NaN
# 3         2022     4114.0      NaN          NaN
# 4         2023     6088.0      NaN          NaN
